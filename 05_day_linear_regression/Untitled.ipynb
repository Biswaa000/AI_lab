# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
X=np.array([[1.5,0.33]])
y=0.65

# %%
# W=np.random.randn(2,3)
W=np.random.randn(1,2)
print(W,W.shape )
# Out:
# [[ 0.41856233 -0.51113639]] (1, 2)

# %%
y_out=np.dot(X,np.transpose(W))
print(y_out)
# Out:
# [[0.45916848]]

# %%
# building the training loop 
epochs=20 
lr=0.1
eList=[]
for epoch in range(epochs):
    #forward pass 
    y_out=np.dot(X,np.transpose(W))
    #compute error
    error =np.square(y-y_out)
    eList.append(error[0][0])
    #compute the gradient
    gradient=-2*(y-y_out)*X

     # backpropagate the error
    W=W-gradient*lr
print(gradient)
print(W)
# Out:
# [[-3.09922669e-06 -6.81829871e-07]]
# [[ 0.53990976 -0.48443995]]

# %%
np.shape(eList)
print(eList)
# Out:
# [0.036416669364452044, 0.010160846835292912, 0.0028350425838520672, 0.0007910232860057601, 0.00022070844458116156, 6.158126868224783e-05, 1.7182181949185857e-05, 4.794110008649802e-06, 1.3376351643234056e-06, 3.7322210579371626e-07, 1.0413507656517398e-07, 2.9055390886263152e-08, 8.106929647512654e-09, 2.2619660691265683e-09, 6.311255580477664e-10, 1.7609436121055956e-10, 4.913320916207655e-11, 1.3708969589586087e-11, 3.825026909480097e-12, 1.0672451169994565e-12]

# %%
plt.plot(range(epochs),eList)
plt.xlabel("epochs")
plt.ylabel("erro")
plt.title("epochs uvs error ")
# Out:
# Text(0.5, 1.0, 'epochs uvs error ')

# %%
def output(X,W): 
    return np.dot(X,np.transpose(W))
print(output(X,W))
# Out:
# [[0.64999945]]
