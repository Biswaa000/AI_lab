# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
X=np.array([[1.5,0.625]])
y=0.5

# %%
# W=np.random.randn(2,3)
W=np.random.randn(1,2)
print(W,W.shape )
# Out:
# [[ 0.89924407 -1.67058935]] (1, 2)

# %%
y_out=np.dot(X,np.transpose(W))
print(y_out)
# Out:
# [[0.30474777]]

# %%
# building the training loop 
epochs=20 
lr=0.1
eList=[]
for epoch in range(epochs):
    #forward pass 
    y_out=np.dot(X,np.transpose(W))
    #compute error
    error =np.square(y-y_out)
    eList.append(error[0][0])
    #compute the gradient
    gradient=-2*(y-y_out)*X

     # backpropagate the error
    W=W-gradient*lr
print(gradient)
print(W)
# Out:
# [[-3.71902991e-07 -1.54959580e-07]]
# [[ 1.01015655 -1.62437582]]

# %%
np.shape(eList)
print(eList)
# Out:
# [0.038123433957037996, 0.008488793141156482, 0.001890165746206124, 0.00042087567557857434, 9.371470975455997e-05, 2.08670810264988e-05, 4.646389789893988e-06, 1.0345931015567915e-06, 2.3036872371665382e-07, 5.1295285834501285e-08, 1.1421716917162997e-08, 2.5432281975321045e-09, 5.662904895791683e-10, 1.2609364699666969e-10, 2.807676997440325e-11, 6.251742501646508e-12, 1.3920505933340526e-12, 3.099623592711891e-13, 6.901808339628476e-14, 1.5367981640741806e-14]

# %%
plt.plot(range(epochs),eList)
plt.xlabel("epochs")
plt.ylabel("erro")
plt.title("epochs uvs error ")
# Out:
# Text(0.5, 1.0, 'epochs uvs error ')

# %%
def output(X,W): 
    return np.dot(X,np.transpose(W))
print(output(X,W))
# Out:
# [[0.49999994]]
